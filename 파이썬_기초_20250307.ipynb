# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/abcd-a/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88_20250307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=100000
print(watch)
# Out:
# 100000

# %%
a ='pig'
b ='dad'
print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)
# Out:
# pig
# dad
# 100000
# pigdad
# pig dad
