# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/abcd-a/blob/20250314/%ED%8C%8C%EC%9D%B4%EC%8D%AC_300%EC%A0%9C_%EB%AC%B8%EC%A0%9C_%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
print("'Mary's cosmetics")
# Out:
# 'Mary's cosmetics

# %%
print('A씨가 아침에 일어나서 한 말이. "좋은아침."')
# Out:
# A씨가 아침에 일어나서 한 말이. "좋은아침."

# %%
print( "c:\\windows")
# Out:
# c:\windows

# %%
print("안녕하세요. \n만나서 \t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서 		반갑습니다.

# %%
print("오늘은", "금요일")
# Out:
# 오늘은 금요일

# %%
print("naver" ,"kakao","sk","samsung", sep =';')
# Out:
# naver;kakao;sk;samsung

# %%
print("naver" ,"kakao","sk","samsung", sep ='/')
# Out:
# naver/kakao/sk/samsung

# %%
print("first");print ("second")
# Out:
# first
# second

# %%
print("first", end="");print ("second")
# Out:
# firstsecond

# %%
print(9/4)
# Out:
# 2.25
