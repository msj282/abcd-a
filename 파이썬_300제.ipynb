# %% [markdown]
# <a href="https://colab.research.google.com/github/msj282/abcd-a/blob/20250328/%ED%8C%8C%EC%9D%B4%EC%8D%AC_300%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000
보유 = 10
총평가금액 = 보유 * 삼성전자
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = '298조'
현재가 = '50,000원'
PER = 15.79

print(시가총액)
print(현재가)
print(PER)
# Out:
# 298조
# 50,000원
# 15.79

# %%
s = 'hello!'
t = 'python'
print(s, t, sep = ' ')
# Out:
# hello! python

# %%
i = 2
j = 3
print( i + i * j)
# Out:
# 8
